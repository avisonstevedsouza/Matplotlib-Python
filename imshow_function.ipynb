# %% [markdown]
# <a href="https://colab.research.google.com/github/avisonstevedsouza/Matplotlib-Python/blob/main/imshow_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %% [markdown]
# # Reading Image using Matplotlib

# %%
img=mpimg.imread('/content/images.jpeg')

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# # Reading Image using OpenCV

# %%
import cv2

# %%
imgcv2=cv2.imread('/content/images.jpeg')

# %%
plt.imshow(imgcv2)
plt.show()
